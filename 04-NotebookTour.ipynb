# %% [markdown]
# # Notebook Tour

# %% [markdown]
# The Jupyter Notebook is a web-based application that enables users to create documents that combine live code wth narrative next, equations, images, visualizations and HTML/JavaScript widgets.
#
# This notebook gives an overview of the Jupyter Notebook and the standard IPython Kernel for running Python code.

# %% [markdown]
# ## Interactive exploration

# %% [markdown]
# First and foremost, Jupyter is an interactive environment for writing and running code. We provide features to make this as pleasant as possible.

# %%
2+4
# Out:
# 6

# %%
import math

# %%
math.atan?

# %% [markdown]
# Inline plotting:

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np
import pandas as pd

# %%
data = {
    'x': np.random.rand(100),
    'y': np.random.rand(100),
    'color': np.random.rand(100),
    'size': 100.0*np.random.rand(100)
}
df = pd.DataFrame(data)

# %%
style.use('seaborn-whitegrid')

# %%
plt.scatter('x', 'y', c='color', s='size', data=df, cmap=plt.cm.Blues)
plt.xlabel('x')
plt.ylabel('y')
plt.title("The data that we collected")

# %% [markdown]
# Seamless access to the system shell:

# %%
# !ls -al
# Out:
# total 35736
# drwxr-xr-x  37 bgranger  staff      1258 May  4 09:10 .
# drwxr-xr-x  53 bgranger  staff      1802 Apr 29 09:14 ..
# -rw-r--r--@  1 bgranger  staff      8196 Apr 29 12:45 .DS_Store
# drwxr-xr-x  12 bgranger  staff       408 Apr 29 09:14 .git
# -rw-r--r--   1 bgranger  staff       575 Apr 29 09:14 .gitignore
# drwxr-xr-x  15 bgranger  staff       510 May  4 09:10 .ipynb_checkpoints
# -rw-r--r--   1 bgranger  staff    828359 May  4 09:09 Bash Examples.ipynb
# -rw-r--r--   1 bgranger  staff   1978750 May  4 09:09 Computational Narratives.ipynb
# -rw-r--r--   1 bgranger  staff    684332 May  4 09:09 Deploying and Scaling.ipynb
# -rw-r--r--   1 bgranger  staff     62950 May  4 09:09 Index.ipynb
# -rw-r--r--   1 bgranger  staff   1411668 Apr 29 13:52 Interaction.ipynb
# -rw-r--r--   1 bgranger  staff     36633 May  4 09:10 Jupyter and IPython.ipynb
# -rw-r--r--   1 bgranger  staff    890612 May  4 09:10 JupyterLab.ipynb
# -rw-r--r--   1 bgranger  staff      1082 Apr 29 09:14 LICENSE
# -rw-r--r--   1 bgranger  staff   1332703 May  4 09:10 Notebook Ecosystem.ipynb
# -rw-r--r--   1 bgranger  staff     51167 Apr 29 09:14 Notebook Tour.ipynb
# -rw-r--r--   1 bgranger  staff      2589 Apr 29 12:49 R Examples.ipynb
# -rw-r--r--   1 bgranger  staff       559 Apr 29 09:14 README.md
# -rw-r--r--   1 bgranger  staff      7687 Apr 29 12:53 Usage in Curriculum.ipynb
# -rw-r--r--   1 bgranger  staff      3219 Apr 29 12:54 Usage in Journalism.ipynb
# -rw-r--r--   1 bgranger  staff      3344 Apr 29 12:54 Usage in Products.ipynb
# -rw-r--r--   1 bgranger  staff  10438700 Apr 29 13:36 Usage in Publishing.ipynb
# -rw-r--r--   1 bgranger  staff    470214 Apr 29 09:14 What is Data Science.ipynb
# drwxr-xr-x   3 bgranger  staff       102 Apr 29 09:14 __pycache__
# -rw-r--r--   1 bgranger  staff      1188 Apr 29 09:35 courses.csv
# drwxr-xr-x   4 bgranger  staff       136 Apr 29 09:14 data
# -rw-r--r--   1 bgranger  staff      1676 Apr 29 09:14 frontmatter.py
# drwxr-xr-x  88 bgranger  staff      2992 Apr 30 11:01 images
# -rw-r--r--   1 bgranger  staff       303 Apr 29 09:14 images-pad.css
# -rw-r--r--   1 bgranger  staff       288 Apr 29 09:14 images.css
# -rw-r--r--   1 bgranger  staff      1192 Apr 29 09:14 ipythonproject.py
# drwxr-xr-x  18 bgranger  staff       612 Apr 29 09:14 ipythonteam
# -rw-r--r--   1 bgranger  staff       606 Apr 29 09:14 load_style.py
# -rw-r--r--   1 bgranger  staff      1327 Apr 29 09:14 lorenz.py
# -rw-r--r--   1 bgranger  staff       972 Apr 29 09:14 talk.css
# -rw-r--r--   1 bgranger  staff      1090 Apr 29 09:14 talktools.py
# -rw-r--r--   1 bgranger  staff        13 Apr 29 09:14 testing.md

# %% [markdown]
# ## Narrative text and equations

# %% [markdown]
# In addition to code cells, the Notebook offers Markdown cells, which enable the user to create narrative text with embedded LaTeX equations. Here is a cell that includes Maxwell's equations:
#
# \begin{aligned}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\   \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0 \end{aligned}

# %% [markdown]
# Markdown cells enable users to create complex narratives that tell stories using code and data.
#
# We are calling this **literate computing** as it is similar to Knuth's [literate programming](http://en.wikipedia.org/wiki/Literate_programming), but involves *live* code and data.

# %% [markdown]
# ## Rich output

# %% [markdown]
# Programming langauges, including Python, allow the writing of textual output to `stdout` and `stderr`. Jupyter and IPython extend this idea and allows objects to declare **rich output representations**:
#
# * JavaScript
# * HTML
# * LaTeX
# * PDF
# * PNG/JPEG
# * SVG
#
# In IPython, the `display` function is like `print` for these rich representations:

# %%
from IPython.display import display

# %% [markdown]
# ### Images

# %% [markdown]
# The `Image` object has a JPEG/PNG representation that is rendered by the Notebook:

# %%
from IPython.display import Image

# %%
i = Image("images/jupyter_logo.png", width="50%")

# %% [markdown]
# If you print the object, you see its textual representation:

# %%
print(i)
# Out:
# <IPython.core.display.Image object>

# %% [markdown]
# However, if you pass the object to `display`, the actual image is shown:

# %%
display(i)

# %% [markdown]
# Or, show the image by returning the object as the final result of an expression:

# %%
i

# %% [markdown]
# ### HTML

# %% [markdown]
# The `HTML` object has an HTML representation:

# %%
from IPython.display import HTML

# %%
s = """<table>
<tr>
<th>Header 1</th>
<th>Header 2</th>
</tr>
<tr>
<td>row 1, cell 1</td>
<td>row 1, cell 2</td>
</tr>
<tr>
<td>row 2, cell 1</td>
<td>row 2, cell 2</td>
</tr>
</table>"""

# %%
h = HTML(s)

# %%
display(h)
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %% [markdown]
# ### JavaScript

# %% [markdown]
# The `Javascript` object has a "representation" that runs JavaScript code in the context of the Notebook.

# %%
from IPython.display import Javascript

# %%
display(Javascript("alert('hi');"))

# %% [markdown]
# ### LaTeX

# %% [markdown]
# This display architecture also understands objects that have a LaTeX representation. This is best illustrated by [SymPy](http://sympy.org/en/index.html), which is a symbolic mathematics package for Python.

# %%
from __future__ import division
from sympy import *
x, y, z = symbols("x y z")
init_printing(use_latex='mathjax')

# %% [markdown]
# When a symbolic expression is passed to `display` or returned from an expression, the LaTeX representation is computed and displayed in the Notebook:

# %%
Rational(3,2)*pi + exp(I*x) / (x**2 + y)
# Out:
#         ⅈ⋅x
# 3⋅π    ℯ
# ─── + ──────
#  2     2
#       x  + y

# %%
(1/cos(x)).series(x, 0, 16)
# Out:
#      2      4       6        8          10           12              14
#     x    5⋅x    61⋅x    277⋅x    50521⋅x     540553⋅x     199360981⋅x      ⎛ 1
# 1 + ── + ──── + ───── + ────── + ───────── + ────────── + ───────────── + O⎝x
#     2     24     720     8064     3628800     95800320     87178291200
#
#
# 6⎞
#  ⎠
