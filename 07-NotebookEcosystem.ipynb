# %% [markdown]
# # Notebook Ecosystem

# %% [markdown]
# There are a wide range of tools that build on top of the Jupyter notebook.

# %%
# %load_ext load_style
# %load_style images.css
from IPython.display import display, Image, HTML
# Out:
# <style>
# .output_png img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
#     margin-top: 16px;
#     margin-bottom: 16px;
#
#     box-shadow: 0 4px 5px 0 rgba(0, 0, 0, 0.14),
#                 0 1px 10px 0 rgba(0, 0, 0, 0.12),
#                 0 2px 4px -1px rgba(0, 0, 0, 0.2);
# }
# </style>

# %% [markdown]
# ## Jupyter nbconvert

# %% [markdown]
# The nbconvert package is a command line tool for running notebooks and converting them to other formats:
#
# * Static HTML
# * Markdown
# * Restructured Text
# * LaTeX/PDF
# * Reveal.js slideshows
#
# https://github.com/ipython/nbconvert

# %% [markdown]
# ## Jupyter nbviewer

# %% [markdown]
# The nbviewer website provides statically rendered HTML versions of any notebook on the internet or GitHub.
#
# http://nbviewer.jupyter.org/

# %%
Image("images/nbviewer1.png", width="80%")

# %% [markdown]
# ## Notebook rendering on GitHub

# %% [markdown]
# * Jupyter notebooks render on GitHub/Gist as of Spring 2015.
# * GitHub is indexing notebook content and tracking the trending notebooks (https://github.com/trending/jupyter-notebook)
# * The notebooks from this talk can be found here (https://github.com/ellisonbg/jupyter-talks)

# %% [markdown]
# ## Binder: live notebooks on GitHub

# %% [markdown]
# The binder project enables Github hosted notebooks to be run by anyone on the internet.
#
# http://mybinder.org/

# %%
Image("images/mybinder.png", width="80%")

# %% [markdown]
# Here are some notable examples:
#
# https://github.com/jupyter-incubator/showcase
#
# https://github.com/SylvainCorlay/bqplot-binder

# %% [markdown]
# ## Jupyter tmpnb

# %% [markdown]
# The tmpnb project provides live, transient notebooks in the cloud.
#
# https://tmpnb.org
#
# https://github.com/jupyter/tmpnb

# %% [markdown]
# ## JupyterHub

# %% [markdown]
# JupyterHub provides persistent, centralized notebooks for organizations:
#
# https://demohub.jupyter.org
#
# https://github.com/jupyterhub
#
# http://jupyterhub-deploy-teaching.readthedocs.org/en/latest/

# %%
Image("images/jupyterhub-admin.png", width="80%")
